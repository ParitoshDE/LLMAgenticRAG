# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=['question', 'section', 'answer'],
    keyword_fields=['course'],
    db_path='faq.db'
)

# %%
from dotenv import load_dotenv
load_dotenv()

from google import genai
gemini_client = genai.Client()

# %%
from rag_helper import RAGBase

assistant = RAGBase(sqlite_index, gemini_client)

# %%
assistant.rag('I just discovered the course, can I still join?')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 assistant.rag('I just discovered the course, can I still join?')
#
# File c:\DataEng\LLMAgenticRAG\rag_helper.py:92, in RAGBase.rag(self, question)
#      90 search_results = self.search(question)
#      91 user_prompt = self.build_prompt(question, search_results)
# ---> 92 return self.llm(user_prompt)
#
# File c:\DataEng\LLMAgenticRAG\rag_helper.py:87, in RAGBase.llm(self, user_prompt)
#      78     response = self.llm_client.models.generate_content(
#      79         model=self.model,
#      80         contents=user_prompt,
#    (...)     83         )
#      84     )
#      85     return response.text
# ---> 87 return _call()
#
# File c:\DataEng\LLMAgenticRAG\.venv\Lib\site-packages\tenacity\__init__.py:331, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     329 copy = self.copy()
#     330 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 331 return copy(f, *args, **kw)
#
# File c:\DataEng\LLMAgenticRAG\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File c:\DataEng\LLMAgenticRAG\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\DataEng\LLMAgenticRAG\.venv\Lib\site-packages\tenacity\__init__.py:353, in BaseRetrying._run_retry(self, retry_state)
#     352 def _run_retry(self, retry_state: "RetryCallState") -> None:
# --> 353     self.iter_state.retry_run_result = self.retry(retry_state)
#
# File c:\DataEng\LLMAgenticRAG\.venv\Lib\site-packages\tenacity\retry.py:82, in retry_if_exception.__call__(self, retry_state)
#      80     if exception is None:
#      81         raise RuntimeError("outcome failed but the exception is None")
# ---> 82     return self.predicate(exception)
#      83 else:
#      84     return False
#
# File c:\DataEng\LLMAgenticRAG\rag_helper.py:72, in RAGBase.llm.<locals>.<lambda>(e)
#      70 def llm(self, user_prompt):
#      71     @retry(
# ---> 72         retry=retry_if_exception(lambda e: isinstance(e, ClientError) and e.status_code == 429),
#      73         wait=wait_exponential(multiplier=1, min=20, max=120),
#      74         stop=stop_after_attempt(5),
#      75         reraise=True
#      76     )
#      77     def _call():
#      78         response = self.llm_client.models.generate_content(
#      79             model=self.model,
#      80             contents=user_prompt,
#    (...)     83             )
#      84         )
#      85         return response.text
#
# AttributeError: 'ClientError' object has no attribute 'status_code'
